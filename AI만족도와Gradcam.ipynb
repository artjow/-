# %% [markdown]
# <a href="https://colab.research.google.com/github/artjow/-/blob/main/AI%EB%A7%8C%EC%A1%B1%EB%8F%84%EC%99%80Gradcam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame #가로축과 세로축이 있는 2차원 데이터를 저장하는 자료구조

# %%
#나눔 폰트 설치 (Nanum)

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
#matplotlib의 폰트를 Nanum 폰트로 지정합니다.

import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# # 2차 실험 일반인의 선호도 (생성 모델과 작가가 만든 작품과의 매치업)
#
# 숫자는 평가에 참여한 일반인 66명의 수를 뜻한다.
#
# 1차 실험을 통해 생성모델의 결과물에 영감을 받아 아티스트는 신작 제작.
#
# 생성모델과 아티스트의 선호도 평균확률(%)은 34:66

# %%
plt.title('Kyungtaek Hong & AI Comparison')
ratio = [29, 39]
labels = ['AI', 'artist']
explode = [0.05, 0.05] #explode는 부채꼴이 파이 차트의 중심에서 벗어나는 정도
colors = ['#ff9999', '#ffc000'] #Hex code사용
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5} 
#wedgeprops는 부채꼴 영역의 스타일을 설정(width:부채꼴 영역의 너비(반지름에 대한 비율), edgecolor:테두리 색상,linewidth:테두리 선의 너비 )

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()
#autopct는 부채꼴 안에 표시될 숫자의 형식을 지정합니다. 소수점 한자리까지 표시하도록 설정
#startangle는 부채꼴이 그려지는 시작 각도를 설정


plt.title(' Donsoon Lee & AI Comparison')
ratio = [28, 38]
labels = ['AI', 'artist']
explode = [0.05, 0.05]
colors = ['#FF8C00', '#32CD32']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5} 

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()


plt.title(' Hanlee Yu & AI Comparison')
ratio = [12, 54]
labels = ['AI', 'artist']
explode = [0.05, 0.05]
colors = ['#90EE90', '#7B68EE']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5} 

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()


plt.title(' Daewon Yang & AI Comparison')
ratio = [22, 44]
labels = ['AI', 'artist']
explode = [0.05, 0.05]
colors = ['#DA70D6', '#00BFFF']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5} 

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()



plt.title(' Changgyeom Kim & AI Comparison')
ratio = [23, 43]
labels = ['AI', 'artist']
explode = [0.05, 0.05]
colors = ['#7CFC00', '#48D1CC']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5} 

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()


plt.title(' Average percentage')
ratio = [34, 66]
labels = ['AI', 'artist']
explode = [0.05, 0.05]
colors = ['#FF4500', '#00FF00']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5} 

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()

# %% [markdown]
# # 가장 선호 하는 이미지와 그 이유

# %%
import pandas as pd

data = pd.read_csv('/content/most favorite image.txt', sep = "\t" , engine='python', encoding = "UTF-8")
data.head(101)
#pd.set_option('display.max_rows', 10000)
# Out:
#       NO  image                                             Reason
# 0      1    4.0                                                익숙함
# 1      2   42.0                               작가의 의도와 인공지능의 우연의 결합
# 2      3   14.0                        경계가 모호한 세상에 있는 듯한 느낌이 좋아서요.
# 3      4    2.0                                                예뻐요
# 4      5   72.0                                      그림이미지 완성도가 높다
# 5      6   90.0           작가의 기존 작업의 느낌이 가장 유지되면서 새로운 이미지로 보이기 때문에
# 6      7    2.0                                 작품 이미지가 잔상에 깊게 남아서
# 7      8   32.0  작가 진술과 맥락이 잘 맞는 것 같다고 생각하며 학습 중 우연이겠지만 가면의 형상이...
# 8      9    NaN                                                 패쓰
# 9     10   24.0                                       작가의 한계를 넘었다.
# 10    11   25.0  작가의 진술을 반영하여 표현된 생성물의 느낌이 감정적으로 다가온다. 작가의 잘 정제...
# 11    12   36.0                                        작업 밀도가 우수하다
# 12    13    NaN                                                 패쓰
# ...

# %%
import pandas as pd

print(data.info())                      # 읽어온 데이터의 정보 확인
print(data.head())                      # 맨 앞의 5개 데이터 보기
print("전체 답변 갯수 : ",len(data))    # 읽어온 데이터의 갯수
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NO      101 non-null    int64
#  1   image   92 non-null     float64
#  2   Reason  81 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.5+ KB
# None
#    NO  image                       Reason
# 0   1    4.0                          익숙함
# 1   2   42.0         작가의 의도와 인공지능의 우연의 결합
# 2   3   14.0  경계가 모호한 세상에 있는 듯한 느낌이 좋아서요.
# 3   4    2.0                          예뻐요
# 4   5   72.0                그림이미지 완성도가 높다
# 전체 답변 갯수 :  101

# %% [markdown]
# # 단어의 사용 빈도
#
# 가장 많이 언급한 단어 순
#
# 1.   느낌이:8
# 2.   잘:7
# 1.   예뻐서:6
# 2.   느껴져서:5
# 1.   기존, 꽃이, 다른, 색감이:4
# 2.   이미지가:3

# %%
#단어들의 사용빈도 확인

file = open('/content/most favorite image.txt', "r")
 
text = file.read() 
 
wordList = text.split()
 
wordCount = {} 
 
for word in wordList:
 
    # Get 명령어를 통해, Dictionary에 Key가 없으면 0리턴
 
    wordCount[word] = wordCount.get(word, 0) + 1 
    
    keys = sorted(wordCount.keys())
 
for word in keys:
 
    print(word + ':' + str(wordCount[word]))
# Out:
# "강렬한:1
# "곤충과:1
# "기존:1
# "시각적으로:1
# "영롱한:1
# "이미지가:1
# "자연의:1
# 1:1
# 10:1
# 100:2
# 101:1
# 11:1
# 12:1
# 13:1
# 14:5
# 15:2
# 16:2
# 17:1
# 18:5
# 19:1
# 2:8
# 20:1
# 21:2
# 22:1
# 23:1
# 24:3
# 25:4
# 26:3
# 27:2
# 28:3
# 29:4
# 3:2
# 30:1
# 31:1
# 32:3
# 33:1
# 34:2
# 35:2
# 36:3
# 37:3
# 38:3
# 39:1
# 3개:1
# 4:3
# 40:1
# 41:1
# 42:9
# 43:2
# 44:6
# 45:1
# 46:1
# 47:1
# 48:2
# 49:3
# 5:1
# 50:1
# 51:1
# 52:2
# 53:1
# 54:1
# 55:1
# 56:1
# 57:2
# 58:1
# 59:1
# 6:1
# 60:1
# 61:3
# 62:3
# 63:1
# 64:1
# 65:1
# 66:1
# 67:1
# 68:1
# 69:1
# 7:2
# 70:1
# 71:1
# 72:2
# 73:1
# 74:1
# 75:2
# 76:1
# 77:1
# 78:2
# 79:1
# 8:1
# 80:4
# 81:1
# 82:2
# 83:3
# 84:1
# 85:3
# 86:1
# 87:1
# 88:3
# 89:2
# 9:1
# 90:2
# 91:1
# 92:1
# 93:1
# 94:2
# 95:3
# 96:2
# 97:4
# 98:2
# 99:1
# NO:1
# Reason:1
# image:1
# 가까이서:1
# 가면:1
# 가면안에:1
# 가면의:1
# 가서:1
# 가장:7
# 가진:1
# 감정이:1
# 감정적으로:1
# 갔다":1
# 강탈":1
# 강하지만:1
# 강한:1
# 갖게:1
# 같고:1
# 같다:1
# 같다.:1
# 같다고:1
# 같아:2
# 같아요.:1
# 같았다:1
# 같았다,":1
# 같았습니다:1
# 같은:2
# 같은데:1
# ...

# %% [markdown]
# # Grad-CAM 클래스 활성화 시각화

# %%
# Display
import numpy as np
import tensorflow as tf
from tensorflow import keras

from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
model_builder = keras.applications.xception.Xception
img_size = (299, 299)
preprocess_input = keras.applications.xception.preprocess_input
decode_predictions = keras.applications.xception.decode_predictions

last_conv_layer_name = "block14_sepconv2_act" #모델의 모든 레이어 이름의 사용할 값을 가져옵니다 model.summary()

# 대상이미지에 대한 local path(경로)
img_path = keras.utils.get_file(
    "donglein.jpg", "https://www.kyeonggi.com/news/photo/197001/2257423_1042726_725.jpg"
)

display(Image(img_path))

# %%
def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299(299x299 PIL(Python Imaging Library)이미지)
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"(배열을 배치로 변환->차원 추가)
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations(input이미지활성화->매핑모델 만듬)
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image(input이미지에 대한 상위예측클래스 기울기 계산)
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)(출력뉴런의 기울기)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient(그라디언트 평균벡터)
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation(모든채널을 합산하여 히트맵 클래스활성화)
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1(0과 1사이의 히트맵으로 시각화)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
# Prepare image
img_array = preprocess_input(get_img_array(img_path, size=img_size))

# Make model
model = model_builder(weights="imagenet")

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=1)[0])

# Generate class activation heatmap
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()
# Out:
# Predicted: [('n03724870', 'mask', 11.307008)]

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))


save_and_display_gradcam(img_path, heatmap)

# %%
img_path = keras.utils.get_file(
    "bts.jpg",
    "https://newsimg.sedaily.com/2019/07/14/1VLOVIXX6I_4.jpg",
)

display(Image(img_path))

# Prepare image
img_array = preprocess_input(get_img_array(img_path, size=img_size))

# Print what the two top predicted classes are
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=2)[0])
# Out:
# Predicted: [('n04548280', 'wall_clock', 8.182938), ('n03938244', 'pillow', 6.9190416)]

# %%
# Prepare image
img_array = preprocess_input(get_img_array(img_path, size=img_size))

# Make model
model = model_builder(weights="imagenet")

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=1)[0])

# Generate class activation heatmap
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()
# Out:
# Predicted: [('n04548280', 'wall_clock', 8.182938)]

# %%
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=260)

save_and_display_gradcam(img_path, heatmap)

# %%
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=80) #클래스 인덱스는 80

save_and_display_gradcam(img_path, heatmap)

# %%
img_path = keras.utils.get_file(
    "fork crane.jpg",
    "https://artlecture.com/data/uploads/2020/9/20200911/150a6a8ab9527571c1377d2f7e85268a.jpg",
)

display(Image(img_path))

# Prepare image
img_array = preprocess_input(get_img_array(img_path, size=img_size))

# Print what the two top predicted classes are
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=2)[0])
# Out:
# Predicted: [('n03476684', 'hair_slide', 6.6917753), ('n01770393', 'scorpion', 5.548222)]

# %%
# Prepare image
img_array = preprocess_input(get_img_array(img_path, size=img_size))

# Make model
model = model_builder(weights="imagenet")

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=1)[0])

# Generate class activation heatmap
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()
# Out:
# Predicted: [('n03476684', 'hair_slide', 6.6917753)]

# %%
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=260)

save_and_display_gradcam(img_path, heatmap)

# %%
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=160)

save_and_display_gradcam(img_path, heatmap)

# %%
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=60)

save_and_display_gradcam(img_path, heatmap)
